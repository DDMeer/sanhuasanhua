# %% [markdown]
# #### 引入各种包

# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook
from openpyxl.styles import PatternFill 
import openpyxl as op

# %% [markdown]
# <table><tr><td bgcolor=yellow><font face="黑体" color=red size=4> 在此处括号内手动输入需要哪三个月。例如，需要3，4，5月的数据的话，a = "3", b = "4", c = "5".</font></td></tr></table>

# %%
a = "3"
b = "4"
c = "5"

# %%
need_a = f'2023.{a}月计划数量'
need_b = f'2023.{b}月计划数量'
need_c = f'2023.{c}月计划数量'


fold_yuanbi = f'2023.{a}月销售单价（原币）'
fold_xiaoshou = f'2023.{a}月销售金额'

# %% [markdown]
# #### 读入从tesla portal上下载的数据并把第7列改为日期格式

# %%
data = pd.read_csv('mydata.csv',encoding='unicode_escape',header = 0,parse_dates=[7])
data
# Out:
#      ï»¿PO Number                                   Ship To Location  \
# 0      7700015506             111 Empire Blvd Brookshire TX 77423 US
# 1      7700010069             45500 Fremont Blvd Fremont CA 94538 US
# 2      7700016554  17100 Murphy Pkwy Megafactory Storage Lathrop ...
# 3      7700016103  17100 Murphy Pkwy Megafactory Storage Lathrop ...
# 4      7700016103  17100 Murphy Pkwy Megafactory Storage Lathrop ...
# ..            ...                                                ...
# 352    7700015506             111 Empire Blvd Brookshire TX 77423 US
# 353    7700015582             111 Empire Blvd Brookshire TX 77423 US
# 354    7700010069             45500 Fremont Blvd Fremont CA 94538 US
# 355    7700015506             111 Empire Blvd Brookshire TX 77423 US
# 356    7700010069             45500 Fremont Blvd Fremont CA 94538 US
#
#      PO Line #  Release Version Release Date   Part Number  \
# 0           20              136      2/24/23  1096215-00-C
# 1          190              349      2/25/23  1547595-A0-F
# 2           40               68      2/24/23  1739701-50-B
# 3           90               72      2/21/23  1693247-47-D
# 4          100               72      2/21/23  1693247-27-D
# ..         ...              ...          ...           ...
# 352         30              136      2/24/23  1631640-00-B
# 353         30              129      2/24/23  1108202-00-M
# 354        190              349      2/25/23  1547595-A0-F
# 355         20              136      2/24/23  1096215-00-C
# 356        170              349      2/25/23  1547595-A2-F
#
#             Part Description  Ship Date   Receipt Date  Open Quantity  \
# 0        HEAT EXCHANGER, 3DU 2023-03-02        4/17/23           4200
# 1         SUPERMANIFOLD, ASY 2023-03-02         3/8/23           2808
# 2        ASY,RAPTOR,TC,MP2XL 2023-03-02        3/11/23             72
# 3      HSNK,BRZD,INS,4HR,BTO 2023-03-03         4/6/23           1512
# 4      HSNK,BRZD,INS,2HR,BTO 2023-03-03        4/20/23            756
# ..                       ...        ...            ...            ...
# 352       HEAT EXCHANGER,4DU 2023-05-30        7/15/23            672
# 353  ELECTRIC OIL PUMP,TESLA 2023-05-30         6/3/23           7800
# 354       SUPERMANIFOLD, ASY 2023-05-30         6/5/23            936
# 355      HEAT EXCHANGER, 3DU 2023-05-30        7/15/23            560
# 356       SUPERMANIFOLD, ASY 2023-05-30         6/5/23            936
#
#     Unit of Measure
# 0                EA
# 1                EA
# 2                EA
# 3                EA
# 4                EA
# ..              ...
# 352              EA
# 353              EA
# 354              EA
# 355              EA
# 356              EA
#
# [357 rows x 11 columns]

# %%
#rename一下因为读进来的时候不知道为啥有乱码

data.rename(columns={"ï»¿PO Number":"PO Number"},inplace=True)
data['Ship Date'] = data['Ship Date'].dt.month
data
# Out:
#       PO Number                                   Ship To Location  PO Line #  \
# 0    7700015506             111 Empire Blvd Brookshire TX 77423 US         20
# 1    7700010069             45500 Fremont Blvd Fremont CA 94538 US        190
# 2    7700016554  17100 Murphy Pkwy Megafactory Storage Lathrop ...         40
# 3    7700016103  17100 Murphy Pkwy Megafactory Storage Lathrop ...         90
# 4    7700016103  17100 Murphy Pkwy Megafactory Storage Lathrop ...        100
# ..          ...                                                ...        ...
# 352  7700015506             111 Empire Blvd Brookshire TX 77423 US         30
# 353  7700015582             111 Empire Blvd Brookshire TX 77423 US         30
# 354  7700010069             45500 Fremont Blvd Fremont CA 94538 US        190
# 355  7700015506             111 Empire Blvd Brookshire TX 77423 US         20
# 356  7700010069             45500 Fremont Blvd Fremont CA 94538 US        170
#
#      Release Version Release Date   Part Number         Part Description  \
# 0                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 1                349      2/25/23  1547595-A0-F       SUPERMANIFOLD, ASY
# 2                 68      2/24/23  1739701-50-B      ASY,RAPTOR,TC,MP2XL
# 3                 72      2/21/23  1693247-47-D    HSNK,BRZD,INS,4HR,BTO
# 4                 72      2/21/23  1693247-27-D    HSNK,BRZD,INS,2HR,BTO
# ..               ...          ...           ...                      ...
# 352              136      2/24/23  1631640-00-B       HEAT EXCHANGER,4DU
# 353              129      2/24/23  1108202-00-M  ELECTRIC OIL PUMP,TESLA
# 354              349      2/25/23  1547595-A0-F       SUPERMANIFOLD, ASY
# 355              136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 356              349      2/25/23  1547595-A2-F       SUPERMANIFOLD, ASY
#
#      Ship Date   Receipt Date  Open Quantity Unit of Measure
# 0            3        4/17/23           4200              EA
# 1            3         3/8/23           2808              EA
# 2            3        3/11/23             72              EA
# 3            3         4/6/23           1512              EA
# 4            3        4/20/23            756              EA
# ..         ...            ...            ...             ...
# 352          5        7/15/23            672              EA
# 353          5         6/3/23           7800              EA
# 354          5         6/5/23            936              EA
# 355          5        7/15/23            560              EA
# 356          5         6/5/23            936              EA
#
# [357 rows x 11 columns]

# %%
data.iloc[1,7]
# Out:
# 3

# %%
f'2023.{a}月计划数量'
# Out:
# '2023.3月计划数量'

# %%
data.to_csv('test.csv')

# %%
#此时的data是350多行，后面400多行是merge的时候的逻辑，所以特殊数据在这里处理

#对绿色特殊数据处理
# 这个函数的输入是指是1月2月还是3月
def specialdata_green_1(x):
    bound = data["Open Quantity"].count()
    tmp = 0#绿色部分有两种特殊数字要处理,这是那个落单的
    
    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1547595-A2-F" and data.iloc[i,0] == 7700015845:
            tmp += data.iloc[i,9]
    return tmp/10000


def specialdata_green_2(x):
    bound = data["Open Quantity"].count()
    tmp = 0#绿色部分有两种特殊数字要处理

    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1547595-A0-F" and data.iloc[i,0] == 7700010069:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1547595-A2-F" and data.iloc[i,0] == 7700010069:
            tmp += data.iloc[i,9]
    return tmp/10000


    



def specialdata_yellow(x):
    bound = data["Open Quantity"].count()
    tmp = 0
    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1693247-47-D" and data.iloc[i,0] == 7700016103:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1693247-27-D" and data.iloc[i,0] == 7700016103:
            tmp += data.iloc[i,9]
    return tmp/10000




def specialdata_red(x):  #红色的那几个数字硬编码
    bound = data["Open Quantity"].count()
    tmp = 0
    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-00-M" and data.iloc[i,0] == 7700013617:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-00-M" and data.iloc[i,0] == 7700015582:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-01-M" and data.iloc[i,0] == 7700002394:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-00-N" and data.iloc[i,0] == 7700013617:
            tmp += data.iloc[i,9]
    return tmp/10000

# %%
#用michael这个表给缺乏物料代码的data表，加上物料代码这列
michael = pd.read_csv('michael.csv',encoding='unicode_escape',header = 0)
michael.rename(columns={"ï»¿Part Number":"Part Number"},inplace=True)
#merge data和michael表，也就是给data表加上物料代码得到data_with_wldm，data_with_wldm是比较全面完整，但是未经分类处理的数据
data_with_wldm = data.merge(michael, on='Part Number',left_index=False, right_index=False, sort=False)

# %%
data_with_wldm
# Out:
#       PO Number                        Ship To Location  PO Line #  \
# 0    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 1    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 2    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 3    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 4    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# ..          ...                                     ...        ...
# 465  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 466  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 467  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 468  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 469  7700013617         550 Milan Dr Sparks NV 89437 US         70
#
#      Release Version Release Date   Part Number         Part Description  \
# 0                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 1                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 2                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 3                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 4                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# ..               ...          ...           ...                      ...
# 465              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 466              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 467              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 468              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 469              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
#
#      Ship Date   Receipt Date  Open Quantity Unit of Measure  \
# 0            3        4/17/23           4200              EA
# 1            3        4/25/23           1680              EA
# 2            3         5/1/23           1960              EA
# 3            3         5/5/23            560              EA
# 4            3         5/6/23           1120              EA
# ..         ...            ...            ...             ...
# 465          4        4/29/23          26400              EA
# 466          5        5/13/23          22200              EA
# 467          5        5/20/23          22800              EA
# 468          5        5/27/23          22800              EA
# 469          5         6/3/23          22200              EA
#
#               need_attach
# 0    S/C/1096215-00-C/#/#
# 1    S/C/1096215-00-C/#/#
# 2    S/C/1096215-00-C/#/#
# 3    S/C/1096215-00-C/#/#
# 4    S/C/1096215-00-C/#/#
# ..                    ...
# 465  S/C/1108202-10-M/#/#
# 466  S/C/1108202-10-M/#/#
# 467  S/C/1108202-10-M/#/#
# 468  S/C/1108202-10-M/#/#
# 469  S/C/1108202-10-M/#/#
#
# [470 rows x 12 columns]

# %% [markdown]
# #### 生成我们想要的数据内容以供填充

# %%
# data_with_wldm.to_csv('test.csv')

# %%
data_with_wldm['Open Quantity'] = data_with_wldm['Open Quantity']/10000

# %%
data_with_wldm.iloc[0,7]
# Out:
# 3

# %%
data_with_wldm
# Out:
#       PO Number                        Ship To Location  PO Line #  \
# 0    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 1    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 2    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 3    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# 4    7700015506  111 Empire Blvd Brookshire TX 77423 US         20
# ..          ...                                     ...        ...
# 465  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 466  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 467  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 468  7700013617         550 Milan Dr Sparks NV 89437 US         70
# 469  7700013617         550 Milan Dr Sparks NV 89437 US         70
#
#      Release Version Release Date   Part Number         Part Description  \
# 0                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 1                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 2                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 3                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# 4                136      2/24/23  1096215-00-C      HEAT EXCHANGER, 3DU
# ..               ...          ...           ...                      ...
# 465              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 466              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 467              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 468              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
# 469              185      2/24/23  1108202-00-N  ELECTRIC OIL PUMP,TESLA
#
#      Ship Date   Receipt Date  Open Quantity Unit of Measure  \
# 0            3        4/17/23          0.420              EA
# 1            3        4/25/23          0.168              EA
# 2            3         5/1/23          0.196              EA
# 3            3         5/5/23          0.056              EA
# 4            3         5/6/23          0.112              EA
# ..         ...            ...            ...             ...
# 465          4        4/29/23          2.640              EA
# 466          5        5/13/23          2.220              EA
# 467          5        5/20/23          2.280              EA
# 468          5        5/27/23          2.280              EA
# 469          5         6/3/23          2.220              EA
#
#               need_attach
# 0    S/C/1096215-00-C/#/#
# 1    S/C/1096215-00-C/#/#
# 2    S/C/1096215-00-C/#/#
# 3    S/C/1096215-00-C/#/#
# 4    S/C/1096215-00-C/#/#
# ..                    ...
# 465  S/C/1108202-10-M/#/#
# 466  S/C/1108202-10-M/#/#
# 467  S/C/1108202-10-M/#/#
# 468  S/C/1108202-10-M/#/#
# 469  S/C/1108202-10-M/#/#
#
# [470 rows x 12 columns]

# %%
# ##提前做特殊数据的预备，因为group by后，有些内容会被程序自动整合，其实对于特殊数据来说那个结果是错的
# bound = data_with_wldm["Open Quantity"].count()
# red_special = 0
# out = []
# for i in range(0, bound):
#     if data_with_wldm.iloc[i,7] == 3 and data_with_wldm.iloc[i,11] == "S/C/1108202-10-M/#/#" and data_with_wldm.iloc[i,5] == "1108202-00-M" and data_with_wldm.iloc[i,0] == 7700013617:
#         tmp = data_with_wldm.iloc[i,9]
#         red_special += tmp
#         out.append(i)
#     elif data_with_wldm.iloc[i,7] == 3 and data_with_wldm.iloc[i,11] == "S/C/1108202-10-M/#/#" and data_with_wldm.iloc[i,5] == "1108202-00-M" and data_with_wldm.iloc[i,0] == 7700015582:
#         tmp = data_with_wldm.iloc[i,9]
#         red_special += tmp
#         out.append(i)
#     elif data_with_wldm.iloc[i,7] == 3 and data_with_wldm.iloc[i,11] == "S/C/1108202-10-M/#/#" and data_with_wldm.iloc[i,5] == "1108202-01-M" and data_with_wldm.iloc[i,0] == 7700002394:
#         tmp = data_with_wldm.iloc[i,9]
#         red_special += tmp
#         out.append(i)
#     elif data_with_wldm.iloc[i,7] == 3 and data_with_wldm.iloc[i,11] == "S/C/1108202-10-M/#/#" and data_with_wldm.iloc[i,5] == "1108202-00-N" and data_with_wldm.iloc[i,0] == 7700013617:
#         tmp = data_with_wldm.iloc[i,9]
#         red_special += tmp
#         out.append(i)
# red_special

# %%
#split方法，dataframe的类型，是从data_with_wldm来的
split = data_with_wldm.groupby(["Part Number","Ship Date"])["Open Quantity"].sum().reset_index(name = "sum")
# split["summp"] = split["sum"]/10000
# split.drop(labels=["sum"],axis=1,inplace=True)
split
# Out:
#      Part Number  Ship Date      sum
# 0   1083849-00-E          3   0.2880
# 1   1083849-00-E          4   0.2720
# 2   1083849-00-E          5   0.2800
# 3   1096215-00-C          3   1.6240
# 4   1096215-00-C          4   1.8480
# 5   1096215-00-C          5   1.3160
# 6   1108202-00-M          3  21.0000
# 7   1108202-00-M          4  18.9600
# 8   1108202-00-M          5   7.6800
# 9   1108202-00-N          4   2.6400
# 10  1108202-00-N          5   9.0000
# 11  1108202-01-M          3   0.2880
# 12  1108202-01-M          4   0.3840
# 13  1108202-01-M          5   0.1920
# 14  1455773-00-F          3   0.8384
# 15  1455773-00-F          4   0.6720
# 16  1455773-00-F          5   0.6656
# 17  1478201-00-B          3   0.8640
# 18  1478201-00-B          4   0.6840
# 19  1478201-00-B          5   0.4680
# 20  1540065-00-C          3   1.2024
# 21  1540065-00-C          4   1.1664
# 22  1540065-00-C          5   0.9360
# 23  1547595-A0-F          3   2.4336
# 24  1547595-A0-F          4   2.0592
# 25  1547595-A0-F          5   2.3400
# 26  1547595-A2-F          3   7.4880
# 27  1547595-A2-F          4   7.1136
# 28  1547595-A2-F          5   8.2368
# 29  1592843-00-A          3   0.2352
# 30  1592843-00-A          4   0.3696
# 31  1592843-00-A          5   0.2016
# 32  1631640-00-A          3   2.0160
# 33  1631640-00-B          4   2.4864
# 34  1631640-00-B          5   1.3440
# 35  1657603-02-E          3   2.8512
# 36  1657603-02-E          4   1.1520
# 37  1657603-02-E          5   1.2096
# 38  1693247-27-D          3   0.5388
# 39  1693247-27-D          4   0.3111
# 40  1693247-27-D          5   0.0707
# 41  1693247-47-D          3   0.8138
# 42  1693247-47-D          4   0.4920
# 43  1693247-47-D          5   0.4570
# 44  1716767-00-A          3   5.5720
# 45  1716767-00-A          4  10.0800
# 46  1716767-00-A          5   6.2440
# 47  1739701-50-B          3   0.0288
# 48  1739701-50-B          4   0.0372
# 49  1739701-50-B          5   0.0392
# 50  1752119-03-B          3   0.7488
# 51  1752119-03-B          4   0.6552
# 52  1752119-03-B          5   0.7488

# %% [markdown]
# ##### 此时得到split，即我们希望的数据的雏形，但是还不够，所以给这个dataframe加上物料代码和po number

# %%
df1 = split
df2 = pd.read_excel('Copy of Exported_Part_Release_Data_Bulk (4).xlsx', sheet_name = 'statistics')

data_to_fill = df1.merge(df2, on='Part Number',left_index=False, right_index=False, sort=False)

#修改下data_to_fill的列的位置
fill_in = data_to_fill["fill_in"]
data_to_fill.drop(labels=["fill_in"],axis=1,inplace = True)
data_to_fill.insert(0, 'fill_in', fill_in)

#改写fill_in 列的名字方便vlookup索引
data_to_fill.rename(columns={"fill_in":"wuliao_code"},inplace=True)

data_to_fill
# Out:
#                                   wuliao_code   Part Number  Ship Date  \
# 0          P/C/1083849-00-E/BH45-01LM018/0122  1083849-00-E          3
# 1          P/C/1083849-00-E/BH45-01LM018/0122  1083849-00-E          4
# 2          P/C/1083849-00-E/BH45-01LM018/0122  1083849-00-E          5
# 3                        S/C/1096215-00-C/#/#  1096215-00-C          3
# 4                        S/C/1096215-00-C/#/#  1096215-00-C          4
# 5                        S/C/1096215-00-C/#/#  1096215-00-C          5
# 6                        S/C/1108202-10-M/#/#  1108202-00-M          3
# 7                        S/C/1108202-10-M/#/#  1108202-00-M          3
# 8                        S/C/1108202-10-M/#/#  1108202-00-M          4
# 9                        S/C/1108202-10-M/#/#  1108202-00-M          4
# 10                       S/C/1108202-10-M/#/#  1108202-00-M          5
# 11                       S/C/1108202-10-M/#/#  1108202-00-M          5
# 12                       S/C/1108202-10-M/#/#  1108202-00-N          4
# 13                       S/C/1108202-10-M/#/#  1108202-00-N          5
# 14                       S/C/1108202-10-M/#/#  1108202-01-M          3
# 15                       S/C/1108202-10-M/#/#  1108202-01-M          4
# 16                       S/C/1108202-10-M/#/#  1108202-01-M          5
# 17                               1455773-00-F  1455773-00-F          3
# 18                               1455773-00-F  1455773-00-F          4
# 19                               1455773-00-F  1455773-00-F          5
# 20                               1478201-00-B  1478201-00-B          3
# 21                               1478201-00-B  1478201-00-B          4
# 22                               1478201-00-B  1478201-00-B          5
# 23             P/M/1540065-00-C/0127-0100008#  1540065-00-C          3
# 24             P/M/1540065-00-C/0127-0100008#  1540065-00-C          4
# 25             P/M/1540065-00-C/0127-0100008#  1540065-00-C          5
# 26             P/M/1547595-A2-F/0127-0100086#  1547595-A0-F          3
# 27             P/M/1547595-A2-F/0127-0100086#  1547595-A0-F          4
# 28             P/M/1547595-A2-F/0127-0100086#  1547595-A0-F          5
# 29             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          3
# 30             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          3
# 31             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          4
# 32             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          4
# 33             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          5
# 34             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          5
# 35                               1592843-00-A  1592843-00-A          3
# 36                               1592843-00-A  1592843-00-A          4
# 37                               1592843-00-A  1592843-00-A          5
# 38                       S/C/1631640-00-A/#/#  1631640-00-A          3
# 39                       S/C/1631640-00-B/#/#  1631640-00-B          4
# 40                       S/C/1631640-00-B/#/#  1631640-00-B          5
# 41                       S/C/1657594-00-A/#/#  1657603-02-E          3
# 42                       S/C/1657594-00-A/#/#  1657603-02-E          4
# 43                       S/C/1657594-00-A/#/#  1657603-02-E          5
# 44                       S/C/1693247-20-C/#/#  1693247-27-D          3
# 45                       S/C/1693247-20-C/#/#  1693247-27-D          4
# 46                       S/C/1693247-20-C/#/#  1693247-27-D          5
# 47                       S/C/1693247-20-C/#/#  1693247-47-D          3
# 48                       S/C/1693247-20-C/#/#  1693247-47-D          4
# 49                       S/C/1693247-20-C/#/#  1693247-47-D          5
# 50                       S/C/1716767-00-A/#/#  1716767-00-A          3
# 51                       S/C/1716767-00-A/#/#  1716767-00-A          4
# 52                       S/C/1716767-00-A/#/#  1716767-00-A          5
# 53                       S/C/1739701-00-B/#/#  1739701-50-B          3
# 54                       S/C/1739701-00-B/#/#  1739701-50-B          4
# 55                       S/C/1739701-00-B/#/#  1739701-50-B          5
# 56  P-Octo2/M/1752119-03-B/0127-0100079/Octo2  1752119-03-B          3
# 57  P-Octo2/M/1752119-03-B/0127-0100079/Octo2  1752119-03-B          4
# 58  P-Octo2/M/1752119-03-B/0127-0100079/Octo2  1752119-03-B          5
#
#         sum          PO
# 0    0.2880  7700006983
# 1    0.2720  7700006983
# 2    0.2800  7700006983
# 3    1.6240  7700015506
# 4    1.8480  7700015506
# 5    1.3160  7700015506
# 6   21.0000  7700013617
# 7   21.0000  7700015582
# 8   18.9600  7700013617
# 9   18.9600  7700015582
# 10   7.6800  7700013617
# 11   7.6800  7700015582
# 12   2.6400  7700013617
# 13   9.0000  7700013617
# 14   0.2880  7700002394
# 15   0.3840  7700002394
# 16   0.1920  7700002394
# 17   0.8384  7700006983
# 18   0.6720  7700006983
# 19   0.6656  7700006983
# 20   0.8640  7700002394
# 21   0.6840  7700002394
# 22   0.4680  7700002394
# 23   1.2024  7700011829
# 24   1.1664  7700011829
# 25   0.9360  7700011829
# 26   2.4336  7700010069
# 27   2.0592  7700010069
# 28   2.3400  7700010069
# 29   7.4880  7700010069
# 30   7.4880  7700015845
# 31   7.1136  7700010069
# 32   7.1136  7700015845
# 33   8.2368  7700010069
# 34   8.2368  7700015845
# 35   0.2352  7700003372
# 36   0.3696  7700003372
# 37   0.2016  7700003372
# 38   2.0160  7700015506
# 39   2.4864  7700015506
# 40   1.3440  7700015506
# 41   2.8512  7700015578
# 42   1.1520  7700015578
# 43   1.2096  7700015578
# 44   0.5388  7700016103
# 45   0.3111  7700016103
# 46   0.0707  7700016103
# 47   0.8138  7700016103
# 48   0.4920  7700016103
# 49   0.4570  7700016103
# 50   5.5720  7700002394
# 51  10.0800  7700002394
# 52   6.2440  7700002394
# 53   0.0288  7700016554
# 54   0.0372  7700016554
# 55   0.0392  7700016554
# 56   0.7488  7700013721
# 57   0.6552  7700013721
# 58   0.7488  7700013721

# %% [markdown]
# #### 把一个大的data_to_fill分成三个小表，后面append到输出的excel上，方便vlookup

# %%
groups = data_to_fill.groupby("Ship Date")
a = int(a)
b = int(b)
c = int(c)

#三个小表
data_to_fill_A = groups.get_group(a)
data_to_fill_B = groups.get_group(b)
data_to_fill_C = groups.get_group(c)

# %%
data_to_fill
# Out:
#                                   wuliao_code   Part Number  Ship Date  \
# 0          P/C/1083849-00-E/BH45-01LM018/0122  1083849-00-E          3
# 1          P/C/1083849-00-E/BH45-01LM018/0122  1083849-00-E          4
# 2          P/C/1083849-00-E/BH45-01LM018/0122  1083849-00-E          5
# 3                        S/C/1096215-00-C/#/#  1096215-00-C          3
# 4                        S/C/1096215-00-C/#/#  1096215-00-C          4
# 5                        S/C/1096215-00-C/#/#  1096215-00-C          5
# 6                        S/C/1108202-10-M/#/#  1108202-00-M          3
# 7                        S/C/1108202-10-M/#/#  1108202-00-M          3
# 8                        S/C/1108202-10-M/#/#  1108202-00-M          4
# 9                        S/C/1108202-10-M/#/#  1108202-00-M          4
# 10                       S/C/1108202-10-M/#/#  1108202-00-M          5
# 11                       S/C/1108202-10-M/#/#  1108202-00-M          5
# 12                       S/C/1108202-10-M/#/#  1108202-00-N          4
# 13                       S/C/1108202-10-M/#/#  1108202-00-N          5
# 14                       S/C/1108202-10-M/#/#  1108202-01-M          3
# 15                       S/C/1108202-10-M/#/#  1108202-01-M          4
# 16                       S/C/1108202-10-M/#/#  1108202-01-M          5
# 17                               1455773-00-F  1455773-00-F          3
# 18                               1455773-00-F  1455773-00-F          4
# 19                               1455773-00-F  1455773-00-F          5
# 20                               1478201-00-B  1478201-00-B          3
# 21                               1478201-00-B  1478201-00-B          4
# 22                               1478201-00-B  1478201-00-B          5
# 23             P/M/1540065-00-C/0127-0100008#  1540065-00-C          3
# 24             P/M/1540065-00-C/0127-0100008#  1540065-00-C          4
# 25             P/M/1540065-00-C/0127-0100008#  1540065-00-C          5
# 26             P/M/1547595-A2-F/0127-0100086#  1547595-A0-F          3
# 27             P/M/1547595-A2-F/0127-0100086#  1547595-A0-F          4
# 28             P/M/1547595-A2-F/0127-0100086#  1547595-A0-F          5
# 29             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          3
# 30             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          3
# 31             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          4
# 32             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          4
# 33             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          5
# 34             P/M/1547595-A2-F/0127-0100086#  1547595-A2-F          5
# 35                               1592843-00-A  1592843-00-A          3
# 36                               1592843-00-A  1592843-00-A          4
# 37                               1592843-00-A  1592843-00-A          5
# 38                       S/C/1631640-00-A/#/#  1631640-00-A          3
# 39                       S/C/1631640-00-B/#/#  1631640-00-B          4
# 40                       S/C/1631640-00-B/#/#  1631640-00-B          5
# 41                       S/C/1657594-00-A/#/#  1657603-02-E          3
# 42                       S/C/1657594-00-A/#/#  1657603-02-E          4
# 43                       S/C/1657594-00-A/#/#  1657603-02-E          5
# 44                       S/C/1693247-20-C/#/#  1693247-27-D          3
# 45                       S/C/1693247-20-C/#/#  1693247-27-D          4
# 46                       S/C/1693247-20-C/#/#  1693247-27-D          5
# 47                       S/C/1693247-20-C/#/#  1693247-47-D          3
# 48                       S/C/1693247-20-C/#/#  1693247-47-D          4
# 49                       S/C/1693247-20-C/#/#  1693247-47-D          5
# 50                       S/C/1716767-00-A/#/#  1716767-00-A          3
# 51                       S/C/1716767-00-A/#/#  1716767-00-A          4
# 52                       S/C/1716767-00-A/#/#  1716767-00-A          5
# 53                       S/C/1739701-00-B/#/#  1739701-50-B          3
# 54                       S/C/1739701-00-B/#/#  1739701-50-B          4
# 55                       S/C/1739701-00-B/#/#  1739701-50-B          5
# 56  P-Octo2/M/1752119-03-B/0127-0100079/Octo2  1752119-03-B          3
# 57  P-Octo2/M/1752119-03-B/0127-0100079/Octo2  1752119-03-B          4
# 58  P-Octo2/M/1752119-03-B/0127-0100079/Octo2  1752119-03-B          5
#
#         sum          PO
# 0    0.2880  7700006983
# 1    0.2720  7700006983
# 2    0.2800  7700006983
# 3    1.6240  7700015506
# 4    1.8480  7700015506
# 5    1.3160  7700015506
# 6   21.0000  7700013617
# 7   21.0000  7700015582
# 8   18.9600  7700013617
# 9   18.9600  7700015582
# 10   7.6800  7700013617
# 11   7.6800  7700015582
# 12   2.6400  7700013617
# 13   9.0000  7700013617
# 14   0.2880  7700002394
# 15   0.3840  7700002394
# 16   0.1920  7700002394
# 17   0.8384  7700006983
# 18   0.6720  7700006983
# 19   0.6656  7700006983
# 20   0.8640  7700002394
# 21   0.6840  7700002394
# 22   0.4680  7700002394
# 23   1.2024  7700011829
# 24   1.1664  7700011829
# 25   0.9360  7700011829
# 26   2.4336  7700010069
# 27   2.0592  7700010069
# 28   2.3400  7700010069
# 29   7.4880  7700010069
# 30   7.4880  7700015845
# 31   7.1136  7700010069
# 32   7.1136  7700015845
# 33   8.2368  7700010069
# 34   8.2368  7700015845
# 35   0.2352  7700003372
# 36   0.3696  7700003372
# 37   0.2016  7700003372
# 38   2.0160  7700015506
# 39   2.4864  7700015506
# 40   1.3440  7700015506
# 41   2.8512  7700015578
# 42   1.1520  7700015578
# 43   1.2096  7700015578
# 44   0.5388  7700016103
# 45   0.3111  7700016103
# 46   0.0707  7700016103
# 47   0.8138  7700016103
# 48   0.4920  7700016103
# 49   0.4570  7700016103
# 50   5.5720  7700002394
# 51  10.0800  7700002394
# 52   6.2440  7700002394
# 53   0.0288  7700016554
# 54   0.0372  7700016554
# 55   0.0392  7700016554
# 56   0.7488  7700013721
# 57   0.6552  7700013721
# 58   0.7488  7700013721

# %% [markdown]
# #### 现在是前期处理，需要把三个data_to_fill的数据填写到我们被要求填写的表里来，以方便做vlookup

# %%
#把客户发展部2023.3-2023.5预测.xlsx这个表稍作修改，方便vlookup了
writer = pd.ExcelWriter('客户发展部2023.3-2023.5预测.xlsx', mode='a', engine='openpyxl',if_sheet_exists='replace')

#把data_to_fill放在客户发展部2023.3-2023.5预测.xlsx一起，这样客户发展部这个表就有两个sheet了
data_to_fill_A.to_excel(writer, sheet_name='工具sheet_A')
data_to_fill_B.to_excel(writer, sheet_name='工具sheet_B')
data_to_fill_C.to_excel(writer, sheet_name='工具sheet_C')
data_to_fill.to_excel(writer, sheet_name='工具sheet_总')

writer.save()
writer.close()

# %%
fold_yuanbi
# Out:
# '2023.3月销售单价（原币）'

# %% [markdown]
# #### 核心：vlookup

# %%
workbook = load_workbook("客户发展部2023.3-2023.5预测.xlsx",data_only=False)#客户发展部2023.3-2023.5预测.xlsx就是我们要填写的表
sheet = workbook["查看销售金额2022.11-2023.1"]
#行和列被隐藏的展开

sheet.column_dimensions.group(start='A', end='CJ', hidden=False)

#先把所有行都展开
sheet.row_dimensions.group(start=1, end=555, hidden=True)



#找到到底在哪几列填
# need_a = "2023.3月计划数量"
# need_b = "2023.4月计划数量"
# need_c = "2023.5月计划数量"
#现在找到具体我们要填的列是fill_in_location_1，fill_in_location_2，fill_in_location_3
for x in range(1, sheet.max_column + 1):
    if sheet.cell(1,x).value.strip() == need_a:
        fill_in_location_A = x
    elif sheet.cell(1,x).value.strip() == need_b:
        fill_in_location_B = x
    elif sheet.cell(1,x).value.strip() == need_c:
        fill_in_location_C = x
#这里需要找到右半部分有需要折叠的几列
# 2023.5月销售单价（原币） 
for y in range(1, sheet.max_column + 1):
    if sheet.cell(1,y).value.strip() == fold_yuanbi:
        fold_location_yuanbi = y
    elif sheet.cell(1,y).value.strip() == fold_xiaoshou:
        fold_location_xiaoshou = y




#出现N/A值不美观，这几个变量用在后面
match_wldm = list(data_to_fill["wuliao_code"])
match_wldm_A = list(data_to_fill_A["wuliao_code"])
match_wldm_B = list(data_to_fill_B["wuliao_code"])
match_wldm_C = list(data_to_fill_C["wuliao_code"])

# %%
#store_hide_row是后面用在折叠显示行的时候用的
store_hide_row = [1]

for i in range(2,sheet.max_row+1):
    if sheet[f"F{i}"].value == "廖剑涛/Kirk Kralapp/Joana" or sheet[f"F{i}"].value == "Jiantao/Joana" or sheet[f"F{i}"].value == "廖剑涛":
        #下面执行填写过程,如果第i行是我们要填的：
        #如果第i行我们能事先确定这次是填不进去内容的，我们就先把它替换成0
        if sheet[f"R{i}"].value not in match_wldm:
            continue
        else:
            #赋值填颜色，对A列操作
            if sheet[f"R{i}"].value not in match_wldm_A:
                sheet.cell(i,fill_in_location_A).value = 0
            else:
                sheet.cell(i,fill_in_location_A).value = f"=VLOOKUP(R{i},'工具sheet_A'!B:F,4,0)"
                sheet.cell(i,fill_in_location_A).fill = PatternFill(start_color="9c0006", fill_type="solid")
            #赋值填颜色，对B列操作
            if sheet[f"R{i}"].value not in match_wldm_B:
                sheet.cell(i,fill_in_location_B).value = 0
            else:
                sheet.cell(i,fill_in_location_B).value = f"=VLOOKUP(R{i},'工具sheet_B'!B:F,4,0)"
                sheet.cell(i,fill_in_location_B).fill = PatternFill(start_color="9c0006", fill_type="solid")
            #赋值填颜色，对C列操作
            if sheet[f"R{i}"].value not in match_wldm_C:
                sheet.cell(i,fill_in_location_C).value = 0
            else:
                sheet.cell(i,fill_in_location_C).value = f"=VLOOKUP(R{i},'工具sheet_C'!B:F,4,0)"
                sheet.cell(i,fill_in_location_C).fill = PatternFill(start_color="9c0006", fill_type="solid")
#         sheet.cell(i,fill_in_location_1).value = '工具sheet'!B5
            if sheet[f"R{i}"].value in match_wldm_A or sheet[f"R{i}"].value in match_wldm_B or sheet[f"R{i}"].value in match_wldm_C:
                #在客户图号填颜色
                sheet.cell(i,24).fill = PatternFill(start_color="90EE90", fill_type="solid")
                store_hide_row.append(i)

# %%
#特殊值要改一下，调用前面的函数
for i in range(2,sheet.max_row+1):
    #红色数字，直接输入替换值，并改变客户图号
    if sheet[f"R{i}"].value == "S/C/1108202-10-M/#/#":
        sheet.cell(i,fill_in_location_A).value = specialdata_red(int(a))
        sheet.cell(i,fill_in_location_B).value = specialdata_red(int(b))
        sheet.cell(i,fill_in_location_C).value = specialdata_red(int(c))
    #黄色数字，输入替换值，改变客户图号
    elif sheet[f"R{i}"].value == "S/C/1693247-20-C/#/#":
        sheet.cell(i,fill_in_location_A).value = specialdata_yellow(int(a))
        sheet.cell(i,fill_in_location_B).value = specialdata_yellow(int(b))
        sheet.cell(i,fill_in_location_C).value = specialdata_yellow(int(c))

green_1 = 85
green_2 = 86
        
#绿色数字，逻辑上有点麻烦，因为85行和86行分别对应那个人是人为规定的，所以硬写了,分别为85行和86行，调用不同的
sheet.cell(green_1,fill_in_location_A).value = specialdata_green_1(int(a))
sheet.cell(green_1,fill_in_location_B).value = specialdata_green_1(int(b))
sheet.cell(green_1,fill_in_location_C).value = specialdata_green_1(int(c))
sheet.cell(green_1,24).value = "1547595-A2-F Austin"


sheet.cell(green_2,fill_in_location_A).value = specialdata_green_2(int(a))
sheet.cell(green_2,fill_in_location_B).value = specialdata_green_2(int(b))
sheet.cell(green_2,fill_in_location_C).value = specialdata_green_2(int(c))
sheet.cell(green_2,24).value = "1547595-A2-F + 1547595-A0-F"

# %%
#此时的data是350多行，后面400多行是merge的时候的逻辑，所以特殊数据在这里处理

#对绿色特殊数据处理
# 这个函数的输入是指是1月2月还是3月



def specialdata_green_1(x):
    bound = data["Open Quantity"].count()
    tmp = 0#绿色部分有两种特殊数字要处理,这是那个落单的
    
    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1547595-A2-F" and data.iloc[i,0] == 7700015845:
            tmp += data.iloc[i,9]
    return tmp


def specialdata_green_2(x):
    bound = data["Open Quantity"].count()
    tmp = 0#绿色部分有两种特殊数字要处理

    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1547595-A0-F" and data.iloc[i,0] == 7700010069:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1547595-A2-F" and data.iloc[i,0] == 7700010069:
            tmp += data.iloc[i,9]
    return tmp


    



def specialdata_yellow(x):
    bound = data["Open Quantity"].count()
    tmp = 0
    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1693247-47-D" and data.iloc[i,0] == 7700016103:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1693247-27-D" and data.iloc[i,0] == 7700016103:
            tmp += data.iloc[i,9]
    return tmp




def specialdata_red(x):  #红色的那几个数字硬编码
    bound = data["Open Quantity"].count()
    tmp = 0
    for i in range(0, bound):
        if data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-00-M" and data.iloc[i,0] == 7700013617:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-00-M" and data.iloc[i,0] == 7700015582:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-01-M" and data.iloc[i,0] == 7700002394:
            tmp += data.iloc[i,9]
        elif data.iloc[i,7] == int(x) and data.iloc[i,5] == "1108202-00-N" and data.iloc[i,0] == 7700013617:
            tmp += data.iloc[i,9]
    return tmp

# %%
#找出哪些行被填进入了颜色，用来后面折起来

# %%
#列的隐藏

# for col in ['A', 'B', 'C','D','E','F','G','H']:
#     sheet.column_dimensions[col].hidden= False
# for col not in ['A', 'B', 'C','D','E']:
#     sheet.column_dimensions[col].hidden= False

# #先展开再隐藏：
# sheet.column_dimensions.group(start='A', end='CJ', hidden=False)
#在表的右半部分有几个不好处理的
column_start1 = op.utils.cell.column_index_from_string('AA')
column_start2 = op.utils.cell.column_index_from_string('BR')

for idx in range(column_start1, fill_in_location_A):
    sheet.column_dimensions[op.utils.get_column_letter(idx)].hidden = True
    
for idx in range(fill_in_location_C+1,fold_location_yuanbi):
    sheet.column_dimensions[op.utils.get_column_letter(idx)].hidden = True
    
for idx in range(column_start2+1,fold_location_xiaoshou):
    sheet.column_dimensions[op.utils.get_column_letter(idx)].hidden = True

    





#隐藏该隐藏的：
sheet.column_dimensions.group(start='A', end='E', hidden=True)
sheet.column_dimensions.group(start='G', end='H', hidden=True)
sheet.column_dimensions.group(start='J', end='M', hidden=True)
sheet.column_dimensions.group(start='O', end='Q', hidden=True)
sheet.column_dimensions.group(start='S', end='T', hidden=True)
sheet.column_dimensions['W'].hidden= True
sheet.column_dimensions.group(start='Y', end='Z', hidden=True)

# %%
#行的隐藏
#先把所有行都展开
# sheet.row_dimensions.group(start=1, end=555, hidden=True)

#找出该显示的
# for x in range(1, sheet.max_row + 1):
#     if sheet.cell(x,6).value == "廖剑涛" or sheet.cell(x,6).value == "廖剑涛/Kirk Kralapp/Joana":
#         store_hide_row.append(x)
#显示
for r in store_hide_row:
    sheet.row_dimensions[r].hidden= False

# %% [markdown]
# #### 保存计算结果

# %%
workbook.save(filename = "output.xlsx")
workbook.close()
